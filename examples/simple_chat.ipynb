# %% [markdown]
# # Simple Chat
#
# A simple demonstration of two agents talking to each other.

# %%
import json
import sys
sys.path.append('..')

import tinytroupe
from tinytroupe.agent import TinyPerson
from tinytroupe.environment import TinyWorld, TinySocialNetwork
from tinytroupe.examples import *
# Out:
# !!!!
# DISCLAIMER: TinyTroupe relies on Artificial Intelligence (AI) models to generate content.
# The AI models are not perfect and may produce inappropriate or inacurate results.
# For any serious or consequential use, please review the generated content before using it.
# !!!!
#
# Looking for default config on: /Users/mstein/repos/TinyTroupe/examples/../tinytroupe/config.ini
# Found custom config on: /Users/mstein/repos/TinyTroupe/examples/config.ini
#
# =================================
# Current TinyTroupe configuration
# =================================
# [OpenAI]
# api_type = openai
# azure_api_version = 2023-05-15
# model = gpt-4o-mini
# max_tokens = 4000
# temperature = 1.5
# freq_penalty = 0.3
# presence_penalty = 0.0
# timeout = 60
# max_attempts = 5
# waiting_time = 2
# exponential_backoff_factor = 5
# embedding_model = text-embedding-3-small
# cache_api_calls = False
# cache_file_name = openai_api_cache.pickle
# max_content_display_length = 1024
#
# [Simulation]
# rai_harmful_content_prevention = True
# rai_copyright_infringement_prevention = True
#
# [Logging]
# loglevel = ERROR

# %%
lisa = create_lisa_the_data_scientist()
oscar = create_oscar_the_architect()

# %%
world = TinyWorld("Chat Room", [lisa, oscar])
world.make_everyone_accessible()

# %%
lisa.listen("Talk to Oscar to know more about him")
world.run(4)
# Out:
# USER --> Lisa: [CONVERSATION]
#           > Talk to Oscar to know more about him
# ──────────────────────────── Chat Room step 1 of 4 ─────────────────────────────
# Lisa acts: [REACH_OUT]
#
# Lisa acts: [TALK]
#           > Hi Oscar! I wanted to take a moment to get to know you better. How
# have you been?
# Lisa acts: [DONE]
#
# Chat Room --> Lisa: [SOCIAL]
#                > Oscar was successfully reached out, and is now available for
# interaction.
# Chat Room --> Oscar: [SOCIAL]
#                > Lisa reached out to you, and is now available for interaction.
# Lisa --> Oscar: [CONVERSATION]
#           > Hi Oscar! I wanted to take a moment to get to know you better. How
# have you been?
# Oscar acts: [THINK]
#            > Lisa wants to get to know me better. I should respond positively
# and share a bit about
#            > myself.
# Oscar acts: [TALK]
#            > Hi Lisa! I'm doing well, thank you for asking. I've been busy with
# work, but I always
#            > enjoy a good chat. How about you?
# Oscar acts: [DONE]
#
# Oscar --> Lisa: [CONVERSATION]
#            > Hi Lisa! I'm doing well, thank you for asking. I've been busy with
# work, but I always
#            > enjoy a good chat. How about you?
# ──────────────────────────── Chat Room step 2 of 4 ─────────────────────────────
# Lisa acts: [THINK]
#           > Oscar seems friendly and open to chatting. I should share a bit
# about myself and ask him
#           > more about his work.
# Lisa acts: [TALK]
#           > I'm doing well too, thanks! I've been working on some interesting
# projects at Microsoft.
#           > What have you been busy with lately?
# Lisa acts: [DONE]
#
# Lisa --> Oscar: [CONVERSATION]
#           > I'm doing well too, thanks! I've been working on some interesting
# projects at Microsoft.
#           > What have you been busy with lately?
# Oscar acts: [THINK]
#            > Lisa is working on interesting projects at Microsoft. I should
# share what I've been
#            > working on and make it sound engaging.
# Oscar acts: [TALK]
#            > I've been busy working on standard designs for new apartment
# buildings at Awesome Inc.
#            > It's a lot of fun, but it can be challenging to balance quality and
# cost. What kind of
#            > projects are you working on at Microsoft?
# Oscar acts: [DONE]
#
# Oscar --> Lisa: [CONVERSATION]
#            > I've been busy working on standard designs for new apartment
# buildings at Awesome Inc.
#            > It's a lot of fun, but it can be challenging to balance quality and
# cost. What kind of
#            > projects are you working on at Microsoft?
# ──────────────────────────── Chat Room step 3 of 4 ─────────────────────────────
# Lisa acts: [THINK]
#           > Oscar is working on standard designs for new apartment buildings. It
# sounds interesting
#           > and challenging. I should explain my projects and how they relate to
# user experience.
# Lisa acts: [TALK]
#           > At Microsoft, I'm currently working on analyzing user behavior and
# feedback data to
#           > improve the relevance of search results. It's quite interesting,
# especially when it
#           > comes to understanding how people interact with technology. I also
# build machine
#           > learning models for various search scenarios. How do you find
# balancing quality and cost
#           > in your designs?
# Lisa acts: [DONE]
#
# Lisa --> Oscar: [CONVERSATION]
#           > At Microsoft, I'm currently working on analyzing user behavior and
# feedback data to
#           > improve the relevance of search results. It's quite interesting,
# especially when it
#           > comes to understanding how people interact with technology. I also
# build machine
#           > learning models for various search scenarios. How do you find
# balancing quality and cost
#           > in your designs?
# Oscar acts: [THINK]
#            > Lisa's work on analyzing user behavior and building machine
# learning models sounds
#            > fascinating. I need to explain how I balance quality and cost in my
# designs, which
#            > often involves trade-offs and discussions with my boss.
# Oscar acts: [TALK]
#            > Balancing quality and cost can be quite tricky. I often have to
# make trade-offs, and my
#            > boss is always pushing for lower costs, which can sometimes
# compromise the quality of
#            > the designs. I try to find solutions that meet both requirements,
# but it can be a
#            > challenge. Your work sounds really interesting! How do you approach
# building those
#            > machine learning models?
# Oscar acts: [DONE]
#
# Oscar --> Lisa: [CONVERSATION]
#            > Balancing quality and cost can be quite tricky. I often have to
# make trade-offs, and my
#            > boss is always pushing for lower costs, which can sometimes
# compromise the quality of
#            > the designs. I try to find solutions that meet both requirements,
# but it can be a
#            > challenge. Your work sounds really interesting! How do you approach
# building those
#            > machine learning models?
# ──────────────────────────── Chat Room step 4 of 4 ─────────────────────────────
# Lisa acts: [THINK]
#           > Oscar faces challenges with balancing quality and cost in his
# designs, which is
#           > relatable. I should explain my approach to building machine learning
# models and how I
#           > ensure they are effective and reliable.
# Lisa acts: [TALK]
#           > I approach building machine learning models by first understanding
# the data and the
#           > problem I'm trying to solve. I focus on cleaning and preprocessing
# the data to ensure
#           > it's reliable, then I experiment with different algorithms to find
# the best fit. I also
#           > make sure to validate the models thoroughly to avoid any biases.
# It's a lot of trial and
#           > error, but I enjoy the process!
# Lisa acts: [DONE]
#
# Lisa --> Oscar: [CONVERSATION]
#           > I approach building machine learning models by first understanding
# the data and the
#           > problem I'm trying to solve. I focus on cleaning and preprocessing
# the data to ensure
#           > it's reliable, then I experiment with different algorithms to find
# the best fit. I also
#           > make sure to validate the models thoroughly to avoid any biases.
# It's a lot of trial and
#           > error, but I enjoy the process!
# Oscar acts: [THINK]
#            > Lisa's approach to building machine learning models is very
# methodical and interesting.
#            > I should acknowledge her process and share my appreciation for the
# trial and error
#            > involved in her work.
# Oscar acts: [TALK]
#            > That sounds like a solid approach! I really admire the attention to
# detail you put into
#            > your work, especially with data cleaning and validation. It must be
# rewarding to see
#            > the models perform well after all that effort. Have you had any
# particularly
#            > interesting projects recently?
# Oscar acts: [DONE]
#
# Oscar --> Lisa: [CONVERSATION]
#            > That sounds like a solid approach! I really admire the attention to
# detail you put into
#            > your work, especially with data cleaning and validation. It must be
# rewarding to see
#            > the models perform well after all that effort. Have you had any
# particularly
#            > interesting projects recently?

# %%
lisa.pp_current_interactions()
# Out:
# >>>>>>>>> Date and time of events: 2025-01-01T13:46:15.514122
# USER --> Lisa: [CONVERSATION]
#           > Talk to Oscar to know more about him
# >>>>>>>>> Date and time of events: 2025-01-01T13:46:15.514122
# Lisa acts: [REACH_OUT]
#
# >>>>>>>>> Date and time of events: 2025-01-01T13:46:15.514122
# Lisa acts: [TALK]
#           > Hi Oscar! I wanted to take a moment to get to know you better. How
# have you been?
# >>>>>>>>> Date and time of events: 2025-01-01T13:46:15.514122
# Lisa acts: [DONE]
#
# >>>>>>>>> Date and time of events: 2025-01-01T13:46:15.514122
# Chat Room --> Lisa: [SOCIAL]
#                > Oscar was successfully reached out, and is now available for
# interaction.
# >>>>>>>>> Date and time of events: 2025-01-01T13:46:15.514122
# Oscar --> Lisa: [CONVERSATION]
#            > Hi Lisa! I'm doing well, thank you for asking. I've been busy with
# work, but I always
#            > enjoy a good chat. How about you?
# >>>>>>>>> Date and time of events: 2025-01-01T13:46:15.514122
# Lisa acts: [THINK]
#           > Oscar seems friendly and open to chatting. I should share a bit
# about myself and ask him
#           > more about his work.
# >>>>>>>>> Date and time of events: 2025-01-01T13:46:15.514122
# Lisa acts: [TALK]
#           > I'm doing well too, thanks! I've been working on some interesting
# projects at Microsoft.
#           > What have you been busy with lately?
# >>>>>>>>> Date and time of events: 2025-01-01T13:46:15.514122
# Lisa acts: [DONE]
#
# >>>>>>>>> Date and time of events: 2025-01-01T13:46:15.514122
# Oscar --> Lisa: [CONVERSATION]
#            > I've been busy working on standard designs for new apartment
# buildings at Awesome Inc.
#            > It's a lot of fun, but it can be challenging to balance quality and
# cost. What kind of
#            > projects are you working on at Microsoft?
# >>>>>>>>> Date and time of events: 2025-01-01T13:46:15.514122
# Lisa acts: [THINK]
#           > Oscar is working on standard designs for new apartment buildings. It
# sounds interesting
#           > and challenging. I should explain my projects and how they relate to
# user experience.
# >>>>>>>>> Date and time of events: 2025-01-01T13:46:15.514122
# Lisa acts: [TALK]
#           > At Microsoft, I'm currently working on analyzing user behavior and
# feedback data to
#           > improve the relevance of search results. It's quite interesting,
# especially when it
#           > comes to understanding how people interact with technology. I also
# build machine
#           > learning models for various search scenarios. How do you find
# balancing quality and cost
#           > in your designs?
# >>>>>>>>> Date and time of events: 2025-01-01T13:46:15.514122
# Lisa acts: [DONE]
#
# >>>>>>>>> Date and time of events: 2025-01-01T13:46:15.514122
# Oscar --> Lisa: [CONVERSATION]
#            > Balancing quality and cost can be quite tricky. I often have to
# make trade-offs, and my
#            > boss is always pushing for lower costs, which can sometimes
# compromise the quality of
#            > the designs. I try to find solutions that meet both requirements,
# but it can be a
#            > challenge. Your work sounds really interesting! How do you approach
# building those
#            > machine learning models?
# >>>>>>>>> Date and time of events: 2025-01-01T13:46:15.514122
# Lisa acts: [THINK]
#           > Oscar faces challenges with balancing quality and cost in his
# designs, which is
#           > relatable. I should explain my approach to building machine learning
# models and how I
#           > ensure they are effective and reliable.
# >>>>>>>>> Date and time of events: 2025-01-01T13:46:15.514122
# Lisa acts: [TALK]
#           > I approach building machine learning models by first understanding
# the data and the
#           > problem I'm trying to solve. I focus on cleaning and preprocessing
# the data to ensure
#           > it's reliable, then I experiment with different algorithms to find
# the best fit. I also
#           > make sure to validate the models thoroughly to avoid any biases.
# It's a lot of trial and
#           > error, but I enjoy the process!
# >>>>>>>>> Date and time of events: 2025-01-01T13:46:15.514122
# Lisa acts: [DONE]
#
# >>>>>>>>> Date and time of events: 2025-01-01T13:46:15.514122
# Oscar --> Lisa: [CONVERSATION]
#            > That sounds like a solid approach! I really admire the attention to
# detail you put into
#            > your work, especially with data cleaning and validation. It must be
# rewarding to see
#            > the models perform well after all that effort. Have you had any
# particularly
#            > interesting projects recently?

# %%
oscar.pp_current_interactions()
# Out:
# >>>>>>>>> Date and time of events: 2025-01-01T13:46:15.514122
# Chat Room --> Oscar: [SOCIAL]
#                > Lisa reached out to you, and is now available for interaction.
# >>>>>>>>> Date and time of events: 2025-01-01T13:46:15.514122
# Lisa --> Oscar: [CONVERSATION]
#           > Hi Oscar! I wanted to take a moment to get to know you better. How
# have you been?
# >>>>>>>>> Date and time of events: 2025-01-01T13:46:15.514122
# Oscar acts: [THINK]
#            > Lisa wants to get to know me better. I should respond positively
# and share a bit about
#            > myself.
# >>>>>>>>> Date and time of events: 2025-01-01T13:46:15.514122
# Oscar acts: [TALK]
#            > Hi Lisa! I'm doing well, thank you for asking. I've been busy with
# work, but I always
#            > enjoy a good chat. How about you?
# >>>>>>>>> Date and time of events: 2025-01-01T13:46:15.514122
# Oscar acts: [DONE]
#
# >>>>>>>>> Date and time of events: 2025-01-01T13:46:15.514122
# Lisa --> Oscar: [CONVERSATION]
#           > I'm doing well too, thanks! I've been working on some interesting
# projects at Microsoft.
#           > What have you been busy with lately?
# >>>>>>>>> Date and time of events: 2025-01-01T13:46:15.514122
# Oscar acts: [THINK]
#            > Lisa is working on interesting projects at Microsoft. I should
# share what I've been
#            > working on and make it sound engaging.
# >>>>>>>>> Date and time of events: 2025-01-01T13:46:15.514122
# Oscar acts: [TALK]
#            > I've been busy working on standard designs for new apartment
# buildings at Awesome Inc.
#            > It's a lot of fun, but it can be challenging to balance quality and
# cost. What kind of
#            > projects are you working on at Microsoft?
# >>>>>>>>> Date and time of events: 2025-01-01T13:46:15.514122
# Oscar acts: [DONE]
#
# >>>>>>>>> Date and time of events: 2025-01-01T13:46:15.514122
# Lisa --> Oscar: [CONVERSATION]
#           > At Microsoft, I'm currently working on analyzing user behavior and
# feedback data to
#           > improve the relevance of search results. It's quite interesting,
# especially when it
#           > comes to understanding how people interact with technology. I also
# build machine
#           > learning models for various search scenarios. How do you find
# balancing quality and cost
#           > in your designs?
# >>>>>>>>> Date and time of events: 2025-01-01T13:46:15.514122
# Oscar acts: [THINK]
#            > Lisa's work on analyzing user behavior and building machine
# learning models sounds
#            > fascinating. I need to explain how I balance quality and cost in my
# designs, which
#            > often involves trade-offs and discussions with my boss.
# >>>>>>>>> Date and time of events: 2025-01-01T13:46:15.514122
# Oscar acts: [TALK]
#            > Balancing quality and cost can be quite tricky. I often have to
# make trade-offs, and my
#            > boss is always pushing for lower costs, which can sometimes
# compromise the quality of
#            > the designs. I try to find solutions that meet both requirements,
# but it can be a
#            > challenge. Your work sounds really interesting! How do you approach
# building those
#            > machine learning models?
# >>>>>>>>> Date and time of events: 2025-01-01T13:46:15.514122
# Oscar acts: [DONE]
#
# >>>>>>>>> Date and time of events: 2025-01-01T13:46:15.514122
# Lisa --> Oscar: [CONVERSATION]
#           > I approach building machine learning models by first understanding
# the data and the
#           > problem I'm trying to solve. I focus on cleaning and preprocessing
# the data to ensure
#           > it's reliable, then I experiment with different algorithms to find
# the best fit. I also
#           > make sure to validate the models thoroughly to avoid any biases.
# It's a lot of trial and
#           > error, but I enjoy the process!
# >>>>>>>>> Date and time of events: 2025-01-01T13:46:15.514122
# Oscar acts: [THINK]
#            > Lisa's approach to building machine learning models is very
# methodical and interesting.
#            > I should acknowledge her process and share my appreciation for the
# trial and error
#            > involved in her work.
# >>>>>>>>> Date and time of events: 2025-01-01T13:46:15.514122
# Oscar acts: [TALK]
#            > That sounds like a solid approach! I really admire the attention to
# detail you put into
#            > your work, especially with data cleaning and validation. It must be
# rewarding to see
#            > the models perform well after all that effort. Have you had any
# particularly
#            > interesting projects recently?
# >>>>>>>>> Date and time of events: 2025-01-01T13:46:15.514122
# Oscar acts: [DONE]
